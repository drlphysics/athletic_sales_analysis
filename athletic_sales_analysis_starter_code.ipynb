# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
df_2020 = pd.read_csv('Resources/athletic_sales_2020.csv')
df_2021 = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
df_2020
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
df_2021
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
df_2020.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
df_2021.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
concat_df = pd.concat([df_2020, df_2021], ignore_index=True)
concat_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
concat_df.isnull().any()
# Out:
# retailer            False
# retailer_id         False
# invoice_date        False
# region              False
# state               False
# city                False
# product             False
# price_per_unit      False
# units_sold          False
# total_sales         False
# operating_profit    False
# sales_method        False
# dtype: bool

# %%
# Check the data type of each column
concat_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
concat_df['invoice_date'] = pd.to_datetime(concat_df['invoice_date'], format = '%m/%d/%y')
concat_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast      New York
# 1     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3     Foot Locker      1185732   2020-01-01  Northeast      New York
# 4     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9639  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9640       Amazon      1185732   2021-12-31  Northeast         Maine
# 9641       Amazon      1185732   2021-12-31  Northeast         Maine
# 9642  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.
concat_df.dtypes
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
concat_df.set_index(['retailer', 'region', 'state', 'city'], inplace=True)

# %%
grouped_df = concat_df.groupby(['region','state','city']).agg({'units_sold': 'sum'})

grouped_df.sort_values(by=['units_sold'], ascending=False)

grouped_df.rename(columns={"units_sold": "Total_Products_Sold"})

# Sort the grouped_df by the 'city' column
grouped_df.sort_values(by='units_sold', ascending=False, inplace=True)
grouped_df.head()
# Out:
#                                     units_sold
# region    state      city
# Northeast New York   New York           111954
# South     Texas      Houston             90322
# West      California San Francisco       85478
#                      Los Angeles         76384
# Southeast Florida    Miami               73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_table = concat_df.pivot_table(index=['region', 'state', 'city'], values='units_sold', aggfunc='sum')



# Rename the "units_sold" column to "Total_Products_Sold"
pivot_table.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)


# Show the top 5 results.
pivot_table.sort_values(by='Total_Products_Sold', ascending=False, inplace=True)
pivot_table.head()
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_df = concat_df.groupby(['region', 'state', 'city']).agg({'total_sales': 'sum'})
grouped_df.rename(columns={'total_sales': 'Total Sales'}, inplace=True)


# Show the top 5 results.
top_regions = grouped_df.sort_values(by='Total Sales', ascending=False).head()
top_regions.head()
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
pivot_table = concat_df.pivot_table(index=['region', 'state', 'city'], values='total_sales', aggfunc='sum')


# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table.rename(columns={'total_sales': 'Total Sales'}, inplace=True)


# Show the top 5 results.
pivot_table = grouped_df.sort_values(by='Total Sales', ascending=False).head()
pivot_table.head()
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_df = concat_df.groupby(['retailer', 'region', 'state', 'city']).agg({'total_sales': 'sum'})
grouped_df.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Show the top 5 results.
top_retailers = grouped_df.sort_values(by='Total Sales', ascending=False).head()
top_retailers.head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
grouped_df = concat_df.groupby(['retailer', 'region', 'state', 'city']).agg({'total_sales': 'sum'})


# Optional: Rename the "total_sales" column to "Total Sales"
grouped_df.rename(columns={'total_sales': 'Total Sales'}, inplace=True)


# Show the top 5 results.
top_retailers = grouped_df.sort_values(by='Total Sales', ascending=False).head()
top_retailers.head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
#women_athletic_footwear_sales = top_retailers[top_retailers['product'] == "Women's Athletic Footwear"]
women_athletic_footwear_sales = concat_df.loc[(concat_df["product"] =="Women's Athletic Footwear")]
women_athletic_footwear_sales.head()
# Out:
#                                                  retailer_id invoice_date  \
# retailer    region    state        city
# Foot Locker Northeast New York     New York          1185732   2020-01-04
#                                    New York          1185732   2020-01-04
#                                    New York          1185732   2020-01-04
# West Gear   Northeast Pennsylvania Philadelphia      1128299   2020-01-05
#                                    Philadelphia      1128299   2020-01-05
#
#                                                                    product  \
# retailer    region    state        city
# Foot Locker Northeast New York     New York      Women's Athletic Footwear
#                                    New York      Women's Athletic Footwear
#                                    New York      Women's Athletic Footwear
# West Gear   Northeast Pennsylvania Philadelphia  Women's Athletic Footwear
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
grouped_df = women_athletic_footwear_sales.groupby(['retailer', 'region', 'state', 'city']).agg({'units_sold': 'sum'})
grouped_df.rename(columns={"units_sold": "Womens_Footwear_Units_Sold_Units"}, inplace=True)

# Show the top 5 results.
top_retailers = grouped_df.sort_values(by='Womens_Footwear_Units_Sold_Units', ascending=False).head()
top_retailers.head()
# Out:
#                                                       Womens_Footwear_Units_Sold_Units
# retailer      region    state          city
# West Gear     West      California     San Francisco                             12107
# Foot Locker   Northeast New York       New York                                  10996
# Kohl's        West      California     Los Angeles                               10826
# Foot Locker   Southeast South Carolina Charleston                                 8814
# Sports Direct South     Texas          Dallas                                     8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
#pivot_table = women_athletic_footwear_sales.pivot_table(index=['retailer', 'region', 'state', 'city'])
#pivot_table.rename(columns={"units_sold": "Womens_Footwear_Units_Sold_Units"}, inplace=True)

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
#top_retailers = pivot_table.sort_values(by='Womens_Footwear_Units_Sold_Units', ascending=False).head()

# Show the top 5 results.
#top_retailers.head()

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pivot_table = concat_df.pivot_table(index='invoice_date', values='total_sales')

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Show the table.
pivot_table.head()
# Out:
#                 Total Sales
# invoice_date
# 2020-01-01    140856.833333
# 2020-01-02    114901.666667
# 2020-01-03    105428.833333
# 2020-01-04    102513.333333
# 2020-01-05    117971.500000

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
daily_sales = pivot_table.resample('D').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
daily_sales.sort_values(by='Total Sales', ascending=True)
daily_sales
# Out:
#                 Total Sales
# invoice_date
# 2020-01-01    140856.833333
# 2020-01-02    114901.666667
# 2020-01-03    105428.833333
# 2020-01-04    102513.333333
# 2020-01-05    117971.500000
# ...                     ...
# 2021-12-27    120470.600000
# 2021-12-28     60202.000000
# 2021-12-29     42221.800000
# 2021-12-30     33580.600000
# 2021-12-31     39731.800000
#
# [731 rows x 1 columns]

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
weekly_sales = pivot_table.resample('W').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
weekly_sales.sort_values(by='Total Sales', ascending=True)

# Sort the resampled pivot table in ascending order on "Total Sales".
weekly_sales
# Out:
#                 Total Sales
# invoice_date
# 2020-01-05    581672.166667
# 2020-01-12    579113.666667
# 2020-01-19    470212.666667
# 2020-01-26    862854.500000
# 2020-02-02    892198.166667
# ...                     ...
# 2021-12-05    679991.317460
# 2021-12-12    720810.150494
# 2021-12-19    673393.334205
# 2021-12-26    643718.555613
# 2022-01-02    296206.800000
#
# [105 rows x 1 columns]
